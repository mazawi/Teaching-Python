# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# - In Python, comments are used to provide explanations or annotations within the code. They are ignored by the Python interpreter and serve as documentation or notes for developers reading the code. Here's how you can use comments in Python:
# - Single-line comments: start with the hash (#) symbol and extend to the end of the line.

# %%
# This is a single-line comment

# %% [markdown]
# - Multi-line comments (using triple quotes): Although Python doesn't have a built-in syntax for multi-line comments, you can use multi-line strings (docstrings) for this purpose.

# %%
'''
multi-line comments
You can type here any number of lines
'''
print ("hi")
# Out:
# hi

# %% [markdown]
# - Comments for inline explanation: Comments can also be used to provide explanations or context for specific lines of code.

# %%
x = 5 # writing in line comments such as defining a variable x which holds 5

# %%
# This is my first application in Python
print ("hi there")
# Out:
# hi there

# %% [markdown]
# # Variables
# •	Does not need declaration, just assigned
#
# C++
#
# int x = 5;
#
# Python
#
# x = 5
#
#
# •	Use same naming convention like other programming languages,
# # wrong
# 3x = 5
#
#
# z-w = 5
#
#
# a@b = 5
#
#
# # Correct
#
# x = 5
#
#
# x_1 = 4
#
#
# Say_Hi = 'Hello'
#
#
# •	The variable is created the first time you assign it a value
# •	Are references to objects
# •	Type information is with the object, not the reference
# •	Everything in Python is an object

# %%
x = 5
y = 1.23
z = 'Hi'

# %% [markdown]
# # Data types
# •	Data type is a property of the object and not of the variable
#
#
# •	Int, float, complex, etc.

# %% [markdown]
# # Print instruction
#
# print('Hi')

# %%
x = 7 
print ('The value of x is:', x)
sq = x*x
print ('The square of x is: ', sq)
# Out:
# The value of x is: 7
# The square of x is:  49

# %% [markdown]
# # float
#
# f1 = 1.234
#
# f2 = 2.3e3    # 2.3 * 10^ 3

# %%
f1 = 1.234

f2 = 2.3e3 

print('f1 = ', f1)
print('f2 = ', f2)
# Out:
# f1 =  1.234
# f2 =  2300.0

# %% [markdown]
# # input instruction
#
# a = input ('Enter a variable')
#
# input() always gives a string
#
#
# ## write a programme that reads a variable and prints the value of the square of the variable

# %%
a = input('Enter a number: ') # input the variable as a string

a = int(a)    # convert the variable into an integer

sq = a*a      # find the square

print('the square is: ', sq)    # print the result
# Out:
# the square is:  1

# %% [markdown]
# # Example 1
# ## write a programme that reads two numbers and finds the sum of these numbers

# %%
# this code was written by Zainab

x = input ("Enter x number:")
x = int (x)
y = input ("Enter y number")
y = int (y)

sum = x+y

print ("the sum is: ", sum)
# Out:
# the sum is:  5

# %% [markdown]
# # Float Numbers

# %%
x = input ("Enter x number:")
x = float (x)
y = input ("Enter y number")
y = float (y)

sum = x+y

print ("the sum is: ", sum)
# Out:
# the sum is:  4.0

# %% [markdown]
# # Strings
#
# myName = 'Mohammad'
#
# myName = "Mohammad"

# %%
s = input ('What is your name:')
print ('Hi, nice to meet you ', s)
# Out:
# Hi, nice to meet you  2

# %% [markdown]
# Repeat printing a string

# %%
s = input ('What is your name:')
print ('Hi, I will repeat your name 5 times ', s*15)
# Out:
# Hi, I will repeat your name 5 times  111111111111111

# %% [markdown]
# # printing different types of variables

# %%
x = 5
y = 1.32
n = "Mohammad"

print(x,  n, y)
# Out:
# 5 Mohammad 1.32

# %% [markdown]
# ![Capture.JPG](data:image/jpeg;base64,...)
# ```
# Operator	Name	Example
# +	Addition	x + y
# -	Subtraction	x - y
# *	Multiplication	x * y
# /	Division	x / y
# %	Modulus	x % y
# **	Exponentiation	x ** y
# //	Floor division	x // y
#
# ```

# %%
x = 8 
y = 3

print('The addition is:', x+y)
print('The multiplication is:', x*y)
print ('The division is: ', x/y)
print('the subtraction is: ', x-y)
print ('the power is:', x**y)
print ('the mode is: ', x%y)
print( 'floor is: ', x//y)
# Out:
# The addition is: 11
# The multiplication is: 24
# The division is:  2.6666666666666665
# the subtraction is:  5
# the power is: 512
# the mode is:  2
# floor is:  2

# %% [markdown]
# # Bitwise logical operators
#
# and, or , not , etc.

# %%
x = 5
y  = 3

print('The AND is:', x&y)
print('The OR is:', x|y)
print ('shift: ', x>>1)
print ('shift: ', x<<1)
# Out:
# The AND is: 1
# The OR is: 7
# shift:  2
# shift:  10
